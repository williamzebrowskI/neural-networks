# %%
# !pip install transformers[torch] datasets
# Out:
# zsh:1: no matches found: transformers[torch]

# %%
# !pip install -U sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from sentence-transformers) (4.42.3)
# Requirement already satisfied: tqdm in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from sentence-transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from sentence-transformers) (2.3.1)
# Requirement already satisfied: numpy in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from sentence-transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from sentence-transformers) (1.14.0)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from sentence-transformers) (0.23.4)
# Requirement already satisfied: Pillow in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from sentence-transformers) (10.3.0)
# Requirement already satisfied: filelock in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.5.0)
# Requirement already satisfied: packaging>=20.9 in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (1.12.1)
# Requirement already satisfied: networkx in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 2.6 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-3.0.1
#
# [notice] A new release of pip is available: 24.1.1 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from sentence_transformers import SentenceTransformer
import torch
# Out:
# /Users/williamzebrowski/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
from datasets import load_dataset
dataset = load_dataset("sentence-transformers/all-nli", "triplet")
train_dataset = dataset["train"].select(range(5000))
eval_dataset = dataset["dev"]
test_dataset = dataset["test"]
# Out:
# Downloading readme:   0%|          | 0.00/5.15k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/38.4M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/782k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/810k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/557850 [00:00<?, ? examples/s]
# Generating dev split:   0%|          | 0/6584 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/6609 [00:00<?, ? examples/s]

# %%
train_dataset
# Out:
# Dataset({
#     features: ['anchor', 'positive', 'negative'],
#     num_rows: 5000
# })

# %%
train_dataset.to_pandas()
# Anchor: The original sentence or query.
# Positive answer: A correct or relevant response to the anchor.
# Negative answer: An incorrect or irrelevant response to the anchor
# Out:
#                                                  anchor  \
# 0     A person on a horse jumps over a broken down a...
# 1                 Children smiling and waving at camera
# 2     A boy is jumping on skateboard in the middle o...
# 3              Two blond women are hugging one another.
# 4     A few people in a restaurant setting, one of t...
# ...                                                 ...
# 4995                            The people are outside.
# 4996                            The people are outside.
# 4997                            The people are outside.
# 4998                            The people are outside.
# 4999                            The people are outside.
#
#                                                positive  \
# 0                     A person is outdoors, on a horse.
# 1                            There are children present
# 2                   The boy does a skateboarding trick.
# 3                    There are women showing affection.
# 4                       The diners are at a restaurant.
# ...                                                 ...
# 4995  People on ATVs and dirt bikes are traveling al...
# 4996  People on ATVs and dirt bikes are traveling al...
# 4997  People on ATVs and dirt bikes are traveling al...
# 4998  People on ATVs and dirt bikes are traveling al...
# 4999  People on ATVs and dirt bikes are traveling al...
#
#                                                negative
# 0         A person is at a diner, ordering an omelette.
# 1                                 The kids are frowning
# 2                     The boy skates down the sidewalk.
# 3                               The women are sleeping.
# 4            The people are sitting at desks in school.
# ...                                                 ...
# 4995  A woman in a pink shirt is handing a bag to th...
# 4996  A small group of adult males enjoy a conversat...
# 4997  Two guys and one girl are sitting at a table i...
# 4998           People sitting on black chairs on a bus.
# 4999     A group of people are staring out of a window.
#
# [5000 rows x 3 columns]

# %%
model = SentenceTransformer("BAAI/bge-large-en")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/90.3k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/720 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]

# %%
# Setting up Training Arguments

from sentence_transformers import SentenceTransformerTrainer, SentenceTransformerTrainingArguments
from sentence_transformers.losses import MultipleNegativesRankingLoss
from sentence_transformers.training_args import BatchSamplers

# %%
# 3. Define a loss function
loss = MultipleNegativesRankingLoss(model)

# %%
args = SentenceTransformerTrainingArguments(
    # Required parameter:
    output_dir="models/mpnet-base-all-nli-triplet",
    # Optional training parameters:
    num_train_epochs=1,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    warmup_ratio=0.1,
    fp16=True,  # Set to False if you get an error that your GPU can't run on FP16
    bf16=False,  # Set to True if you have a GPU that supports BF16
    batch_sampler=BatchSamplers.NO_DUPLICATES,  # MultipleNegativesRankingLoss benefits from no duplicate samples in a batch
    # Optional tracking/debugging parameters:
    eval_strategy="steps",
    eval_steps=100,
    save_strategy="steps",
    save_steps=100,
    save_total_limit=2,
    logging_steps=100,
    run_name="mpnet-base-all-nli-triplet",  # Will be used in W&B if `wandb` is installed
)

# %%
trainer = SentenceTransformerTrainer(
    model=model,
    args=args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    loss=loss
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 trainer = SentenceTransformerTrainer(
#       2     model=model,
#       3     args=args,
#       4     train_dataset=train_dataset,
#       5     eval_dataset=eval_dataset,
#       6     loss=loss
#       7 )
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages/sentence_transformers/trainer.py:187, in SentenceTransformerTrainer.__init__(self, model, args, train_dataset, eval_dataset, loss, evaluator, data_collator, tokenizer, model_init, compute_metrics, callbacks, optimizers, preprocess_logits_for_metrics)
#     185 if isinstance(eval_dataset, dict) and not isinstance(eval_dataset, Dataset):
#     186     eval_dataset = DatasetDict(eval_dataset)
# --> 187 super().__init__(
#     188     model=None if self.model_init else model,
#     189     args=args,
#     190     data_collator=data_collator,
#     191     train_dataset=train_dataset,
#     192     eval_dataset=eval_dataset,
#     193     tokenizer=tokenizer,
#     194     model_init=model_init,
#     195     compute_metrics=compute_metrics,
#     196     callbacks=callbacks,
#     197     optimizers=optimizers,
#     198     preprocess_logits_for_metrics=preprocess_logits_for_metrics,
#     199 )
#     200 # Every Sentence Transformer model can always return a loss, so we set this to True
#     201 # to avoid having to specify it in the data collator or model's forward
#     202 self.can_return_loss = True
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages/transformers/trainer.py:403, in Trainer.__init__(self, model, args, data_collator, train_dataset, eval_dataset, tokenizer, model_init, compute_metrics, callbacks, optimizers, preprocess_logits_for_metrics)
#     400 self.deepspeed = None
#     401 self.is_in_train = False
# --> 403 self.create_accelerator_and_postprocess()
#     405 # memory metrics - must set up as early as possible
#     406 self._memory_tracker = TrainerMemoryTracker(self.args.skip_memory_metrics)
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages/transformers/trainer.py:4604, in Trainer.create_accelerator_and_postprocess(self)
#    4601     args.update(accelerator_config)
#    4603 # create accelerator object
# -> 4604 self.accelerator = Accelerator(**args)
#    4605 # some Trainer classes need to use `gather` instead of `gather_for_metrics`, thus we store a flag
#    4606 self.gather_function = self.accelerator.gather_for_metrics
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/transform_llm/.venv/lib/python3.11/site-packages/accelerate/accelerator.py:467, in Accelerator.__init__(self, device_placement, split_batches, mixed_precision, gradient_accumulation_steps, cpu, dataloader_config, deepspeed_plugin, fsdp_plugin, megatron_lm_plugin, rng_types, log_with, project_dir, project_config, gradient_accumulation_plugin, dispatch_batches, even_batches, use_seedable_sampler, step_scheduler_with_optimizer, kwargs_handlers, dynamo_backend)
#     463 self.native_amp = True
#     464 if self.device.type not in ("xpu", "cuda", "npu", "xla", "mlu") or is_torch_xla_available(
#     465     check_is_tpu=True
#     466 ):
# --> 467     raise ValueError(f"fp16 mixed precision requires a GPU (not {self.device.type!r}).")
#     468 kwargs = self.scaler_handler.to_kwargs() if self.scaler_handler is not None else {}
#     469 if self.distributed_type == DistributedType.FSDP:
#
# ValueError: fp16 mixed precision requires a GPU (not 'mps').

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='313' max='313' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [313/313 08:36, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.664200</td>
#       <td>0.639940</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.142100</td>
#       <td>0.817364</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.363200</td>
#       <td>1.056603</td>
#     </tr>
#   </tbody>
# </table><p>
# Computing widget examples:   0%|          | 0/1 [00:00<?, ?example/s]
# TrainOutput(global_step=313, training_loss=0.42413954079722443, metrics={'train_runtime': 520.1962, 'train_samples_per_second': 9.612, 'train_steps_per_second': 0.602, 'total_flos': 0.0, 'train_loss': 0.42413954079722443, 'epoch': 1.0})

# %%
from sentence_transformers.evaluation import TripletEvaluator

test_evaluator = TripletEvaluator(
    anchors=test_dataset["anchor"],
    positives=test_dataset["positive"],
    negatives=test_dataset["negative"],
    name="all-nli-test",
)

test_evaluator(model)
# Out:
# {'all-nli-test_cosine_accuracy': 0.8853079134513542,
#  'all-nli-test_dot_accuracy': 0.11469208654864578,
#  'all-nli-test_manhattan_accuracy': 0.885761839915267,
#  'all-nli-test_euclidean_accuracy': 0.8853079134513542,
#  'all-nli-test_max_accuracy': 0.885761839915267}

# %%
# 8. Save the trained model
model.save_pretrained("models/wz-mpnet-base-all-nli-triplet/final")

# 9. (Optional) Push it to the Hugging Face Hub
model.push_to_hub("mpnet-base-all-nli-triplet")
